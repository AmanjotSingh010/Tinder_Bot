# %%
from random import randint
from time import sleep

from goto import with_goto
from selenium import webdriver
from selenium.webdriver.common.keys import Keys


class TinderAutoSwipeBot():
    def __init__(self):
        self.driver = webdriver.Chrome()

    # Open New Browser window with Tinder Web
    def login(self):
        self.driver.get('https://tinder.com')
        # executor_url = self.driver.command_executor._url
        # session_id = self.driver.session_id
        # print(executor_url)
        # print(session_id)

    # Stop the Bot
    def stop(self):
        print('Stopping Bot')
        self.driver.close()

    # Like Profile
    def like(self):
        self.driver.find_element_by_tag_name('body').send_keys(Keys.ARROW_RIGHT)
        print('Liking....')

    # Dislike Profile
    def dislike(self):
        self.driver.find_element_by_tag_name('body').send_keys(Keys.ARROW_LEFT)
        print('Disliking....')

    # Auto Swiping Functionality
    def auto_swipe(self):
        print('Auto Swiping Starts')
        random = randint(0, 5)
        likes = 0
        dislikes = 0
        while True:
            sleep(0.5)
            if random > 0:
                self.like()
                sleep(2)
                likes = likes + 1
                print('Liked - {}'.format(likes))
                random = random - 1
            else:
                self.dislike()
                sleep(2)
                dislikes = dislikes + 1
                print('Disliked - {}'.format(dislikes))
                random = randint(0, 5)


@with_goto
def main():
    # Call the Bot
    bot = TinderAutoSwipeBot()
    # Start Login Process
    bot.login()

    print('---------------------------------------------------------------------------------------')
    print('STEP 1: Kindly login to your Tinder account manually in newly open browser screen. '
          'Allow all required permission location, notification etc')
    print('STEP 2: One You done with login. Input Yes or 1 and Hit Enter Key')
    print('STEP 3: Enjoy! Auto Swiping :)')
    print('---------------------------------------------------------------------------------------')

    # Start the Auto Liking / Disliking
    label.begin
    answer = input("Have you logged in? (Yes | 1): ")
    if answer.lower() == '1' or answer.lower() == 'yes':
        bot.auto_swipe()
    else:
        print("Enter Correct Value: Yes or 1")
        goto.begin


main()
# Out:
# ---------------------------------------------------------------------------------------
# STEP 1: Kindly login to your Tinder account manually in newly open browser screen. Allow all required permission location, notification etc
# STEP 2: One You done with login. Input Yes or 1 and Hit Enter Key
# STEP 3: Enjoy! Auto Swiping :)
# ---------------------------------------------------------------------------------------
# Have you logged in? (Yes | 1): yes
# Auto Swiping Starts
# Liking....
# Liked - 1
# Liking....
# Liked - 2
# Disliking....
# Disliked - 1
# Liking....
# Liked - 3
# Liking....
# Liked - 4
# Liking....
# Liked - 5
# Liking....
# Liked - 6
# Liking....
# Liked - 7
# Disliking....
# Disliked - 2
# Liking....
# Liked - 8
# Liking....
# Liked - 9
# Liking....
# Liked - 10
# Liking....
# Liked - 11
# Disliking....
# Disliked - 3
# Liking....
# Liked - 12
# Disliking....
# Disliked - 4
# Liking....
# Liked - 13
# Liking....
# Liked - 14
# Disliking....
# Disliked - 5
# Liking....
# Liked - 15
# Liking....
# Liked - 16
# Disliking....
# Disliked - 6
# Disliking....
# Disliked - 7
# Liking....
# Liked - 17
# Disliking....
# Disliked - 8
# Liking....
# Liked - 18
# Disliking....
# Disliked - 9
# Liking....
# Liked - 19
# Liking....
# Liked - 20
# Liking....
# Liked - 21
# Liking....
# Liked - 22
# Disliking....
# Disliked - 10
# Liking....
# Liked - 23
# Liking....
# Liked - 24
# Liking....
# Liked - 25
# Liking....
# Liked - 26
# Liking....
# Liked - 27
# Disliking....
# Disliked - 11
# Liking....
# Liked - 28
# Liking....
# Liked - 29
# Disliking....
# Disliked - 12
# Liking....
# Liked - 30
# Liking....
# Liked - 31
# Liking....
# Liked - 32
# Liking....
# Liked - 33
# Disliking....
# Disliked - 13
# Disliking....
# Disliked - 14
# Liking....
# Liked - 34
# Liking....
# Liked - 35
# Liking....
# Liked - 36
# Disliking....
# Disliked - 15
# Disliking....
# Disliked - 16
# Liking....
# Liked - 37
# Disliking....
# Disliked - 17
# Liking....
# Liked - 38
# Disliking....
# Disliked - 18
# Liking....
# Liked - 39
# Disliking....
# Disliked - 19
# Liking....
# Liked - 40
# Disliking....
# Disliked - 20
# Liking....
# Liked - 41
# Liking....
# Liked - 42
# Liking....
# Liked - 43
# Liking....
# Liked - 44
# Disliking....
# Disliked - 21
# Liking....
# Liked - 45
# Liking....
# Liked - 46
# Liking....
# Liked - 47
# Liking....
# Liked - 48
# Liking....
# Liked - 49
# Disliking....
# Disliked - 22
# Liking....
# Liked - 50
# Liking....
# Liked - 51
# Liking....
# Liked - 52
# Liking....
# Liked - 53
# Liking....
# Liked - 54
# Disliking....
# Disliked - 23
# Liking....
# Liked - 55
# Liking....
# Liked - 56
# Liking....
# Liked - 57
# Liking....
# Liked - 58
# Liking....
# Liked - 59
# Disliking....
# Disliked - 24
# Liking....
# Liked - 60
# Liking....
# Liked - 61
# Liking....
# Liked - 62
# Disliking....
# Disliked - 25
# Liking....
# Liked - 63
# Disliking....
# Disliked - 26
# Liking....
# Liked - 64
# Liking....
# Liked - 65
# Disliking....
# Disliked - 27
# Liking....
# Liked - 66
# Disliking....
# Disliked - 28
# Liking....
# Liked - 67
# Disliking....
# Disliked - 29
# Disliking....
# Disliked - 30
# Disliking....
# Disliked - 31
# Liking....
# Liked - 68
# Liking....
# Liked - 69
# Liking....
# Liked - 70
# Disliking....
# Disliked - 32
# Liking....
# Liked - 71
# Liking....
# Liked - 72
# Disliking....
# Disliked - 33
# Liking....
# Liked - 73
# Liking....
# Liked - 74
# Liking....
# Liked - 75
# Liking....
# Liked - 76
# Liking....
# Liked - 77
# Disliking....
# Disliked - 34
# Liking....
# Liked - 78
# Disliking....
# Disliked - 35
# Liking....
# Liked - 79
# Liking....
# Liked - 80
# Liking....
# Liked - 81
# Liking....
# Liked - 82
# Liking....
# Liked - 83
# Disliking....
# Disliked - 36
# Disliking....
# Disliked - 37
# Liking....
# Liked - 84
# Liking....
# Liked - 85
# Liking....
# Liked - 86
# Liking....
# Liked - 87
# Disliking....
# Disliked - 38
# Liking....
# Liked - 88
# Liking....
# Liked - 89
# Liking....
# Liked - 90
# Disliking....
# Disliked - 39
# Disliking....
# Disliked - 40
# Disliking....
# Disliked - 41
# Liking....
# Liked - 91
# Liking....
# Liked - 92
# Liking....
# Liked - 93
# Disliking....
# Disliked - 42
# Liking....
# Liked - 94
# Liking....
# Liked - 95
# Disliking....
# Disliked - 43
# Liking....
# Liked - 96
# Liking....
# Liked - 97
# Liking....
# Liked - 98
# Liking....
# Liked - 99
# Disliking....
# Disliked - 44
# Liking....
# Liked - 100
# Liking....
# Liked - 101
# Disliking....
# Disliked - 45
# Liking....
# Liked - 102
# Liking....
# Liked - 103
# Liking....
# Liked - 104
# Disliking....
# Disliked - 46
# Liking....
# Liked - 105
# Disliking....
# Disliked - 47
# Liking....
# Liked - 106
# Liking....
# Liked - 107
# Liking....
# Liked - 108
# Liking....
# Liked - 109
# Disliking....
# Disliked - 48
# Liking....
# Liked - 110
# Liking....
# Liked - 111
# Liking....
# Liked - 112
# Liking....
# Liked - 113
# Disliking....
# Disliked - 49
# Liking....
# Liked - 114
# Liking....
# Liked - 115
# Liking....
# Liked - 116
# Liking....
# Liked - 117
# Disliking....
# Disliked - 50
# Liking....
# Liked - 118
# Disliking....
# Disliked - 51
# Liking....
# Liked - 119
# Liking....
# Liked - 120
# Liking....
# Liked - 121
# Disliking....
# Disliked - 52
# Liking....
# Liked - 122
# Disliking....
# Disliked - 53
# Liking....
# Liked - 123
# Liking....
# Liked - 124
# Liking....
# Liked - 125
# Liking....
# Liked - 126
# Disliking....
# Disliked - 54
# Liking....
# Liked - 127
# Liking....
# Liked - 128
# Liking....
# Liked - 129
# Disliking....
# Disliked - 55
# Liking....
# Liked - 130
# Liking....
# Liked - 131
# Disliking....
# Disliked - 56
# Liking....
# Liked - 132
# Liking....
# Liked - 133
# Liking....
# Liked - 134
# Liking....
# Liked - 135
# Disliking....
# Disliked - 57
# Liking....
# Liked - 136
# Liking....
# Liked - 137
# Liking....
# Liked - 138
# Disliking....
# Disliked - 58
# Liking....
# Liked - 139
# Disliking....
# Disliked - 59
# Liking....
# Liked - 140
# Liking....
# Liked - 141
# Liking....
# Liked - 142
# Liking....
# Liked - 143
# Liking....
# Liked - 144
# Disliking....
# Disliked - 60
# Liking....
# Liked - 145
# Liking....
# Liked - 146
# Liking....
# Liked - 147
# Disliking....
# Disliked - 61
# Liking....
# Liked - 148
# Liking....
# Liked - 149
# Liking....
# Liked - 150
# Liking....
# Liked - 151
# Liking....
# Liked - 152
# Disliking....
# Disliked - 62
# Disliking....
# Disliked - 63
# Disliking....
# Disliked - 64
# Disliking....
# Disliked - 65
# Liking....
# Liked - 153
# Disliking....
# Disliked - 66
# Liking....
# Liked - 154
# Liking....
# Liked - 155
# Liking....
# Liked - 156
# Liking....
# Liked - 157
# Disliking....
# Disliked - 67
# Liking....
# Liked - 158
# Liking....
# Liked - 159
# Disliking....
# Disliked - 68
# Liking....
# Liked - 160
# Liking....
# Liked - 161
# Liking....
# Liked - 162
# Liking....
# Liked - 163
# Liking....
# Liked - 164
# Disliking....
# Disliked - 69
# Liking....
# Liked - 165
# Liking....
# Liked - 166
# Liking....
# Liked - 167
# Disliking....
# Disliked - 70
# Liking....
# Liked - 168
# Liking....
# Liked - 169
# Liking....
# Liked - 170
# Liking....
# Liked - 171
# Disliking....
# Disliked - 71
# Disliking....
# Disliked - 72
# Liking....
# Liked - 172
# Disliking....
# Disliked - 73
# Liking....
# Liked - 173
# Liking....
# Liked - 174
# Disliking....
# Disliked - 74
# Liking....
# Liked - 175
# Disliking....
# Disliked - 75
# Liking....
# Liked - 176
# Liking....
# Liked - 177
# Liking....
# Liked - 178
# Liking....
# Liked - 179
# Liking....
# Liked - 180
# Disliking....
# Disliked - 76
# Liking....
# Liked - 181
# Liking....
# Liked - 182
# Liking....
# Liked - 183
# Liking....
# Liked - 184
# Liking....
# Liked - 185
# Disliking....
# Disliked - 77
# Liking....
# Liked - 186
# Liking....
# Liked - 187
# Liking....
# Liked - 188
# Liking....
# Liked - 189
# Disliking....
# Disliked - 78
# Liking....
# Liked - 190
# Liking....
# Liked - 191
# Liking....
# Liked - 192
# Liking....
# Liked - 193
# Liking....
# Liked - 194
# Disliking....
# Disliked - 79
# Liking....
# Liked - 195
# Disliking....
# Disliked - 80
# Liking....
# Liked - 196
# Liking....
# Liked - 197
# Liking....
# Liked - 198
# Liking....
# Liked - 199
# Disliking....
# Disliked - 81
# Liking....
# Liked - 200
# Liking....
# Liked - 201
# Liking....
# Liked - 202
# Liking....
# Liked - 203
# Liking....
# Liked - 204
# Disliking....
# Disliked - 82
# Liking....
# Liked - 205
# Liking....
# Liked - 206
# Liking....
# Liked - 207
# Liking....
# Liked - 208
# Disliking....
# Disliked - 83
# Liking....
# Liked - 209
# Liking....
# Liked - 210
# Disliking....
# Disliked - 84
# Disliking....
# Disliked - 85
# Liking....
# Liked - 211
# Liking....
# Liked - 212
# Liking....
# Liked - 213
# Liking....
# Liked - 214
# Disliking....
# Disliked - 86
# Disliking....
# Disliked - 87
# Liking....
# Liked - 215
# Liking....
# Liked - 216
# Liking....
# Liked - 217
# Liking....
# Liked - 218
# Disliking....
# Disliked - 88
# Liking....
# Liked - 219
# Liking....
# Liked - 220
# Disliking....
# Disliked - 89
# Liking....
# Liked - 221
# Liking....
# Liked - 222
# Disliking....
# Disliked - 90
# Liking....
# Liked - 223
# Liking....
# Liked - 224
# Liking....
# Liked - 225
# Liking....
# Liked - 226
# Liking....
# Liked - 227
# Disliking....
# Disliked - 91
# Liking....
# Liked - 228
# Liking....
# Liked - 229
# Liking....
# Liked - 230
# Disliking....
# Disliked - 92
# Liking....
# Liked - 231
# Liking....
# Liked - 232
# Disliking....
# Disliked - 93
# Liking....
# Liked - 233
# Liking....
# Liked - 234
# Liking....
# Liked - 235
# Liking....
# Liked - 236
# Disliking....
# Disliked - 94
# Liking....
# Liked - 237
# Liking....
# Liked - 238
# Liking....
# Liked - 239
# Liking....
# Liked - 240
# Disliking....
# Disliked - 95
# Liking....
# Liked - 241
# Liking....
# Liked - 242
# Liking....
# Liked - 243
# Liking....
# Liked - 244
# Liking....
# Liked - 245
# Disliking....
# Disliked - 96
# Liking....
# Liked - 246
# Liking....
# Liked - 247
# Liking....
# Liked - 248
# Disliking....
# Disliked - 97
# Liking....
# Liked - 249
# Liking....
# Liked - 250
# Disliking....
# Disliked - 98
# Liking....
# Liked - 251
# Liking....
# Liked - 252
# Liking....
# Liked - 253
# Liking....
# Liked - 254
# Liking....
# Liked - 255
# Disliking....
# Disliked - 99
# Disliking....
# Disliked - 100
# Liking....
# Liked - 256
# Disliking....
# Disliked - 101
# Liking....
# Liked - 257
# Liking....
# Liked - 258
# Disliking....
# Disliked - 102
# Liking....
# Liked - 259
# Liking....
# Liked - 260
# Liking....
# Liked - 261
# Liking....
# Liked - 262
# Disliking....
# Disliked - 103
# Liking....
# Liked - 263
# Liking....
# Liked - 264
# Liking....
# Liked - 265
# Liking....
# Liked - 266
# Liking....
# Liked - 267
# Disliking....
# Disliked - 104
# Liking....
# Liked - 268
# Liking....
# Liked - 269
# Liking....
# Liked - 270
# Disliking....
# Disliked - 105
# Liking....
# Liked - 271
# Liking....
# Liked - 272
# Disliking....
# Disliked - 106
# Liking....
# Liked - 273
# Liking....
# Liked - 274
# Disliking....
# Disliked - 107
# Liking....
# Liked - 275
# Liking....
# Liked - 276
# Disliking....
# Disliked - 108
# Liking....
# Liked - 277
# Liking....
# Liked - 278
# Disliking....
# Disliked - 109
# Liking....
# Liked - 279
# Disliking....
# Disliked - 110
# Liking....
# Liked - 280
# Liking....
# Liked - 281
# Disliking....
# Disliked - 111
# Liking....
# Liked - 282
# Liking....
# Liked - 283
# Liking....
# Liked - 284
# Liking....
# Liked - 285
# Disliking....
# Disliked - 112
# Disliking....
# Disliked - 113
# Liking....
# Liked - 286
# Liking....
# Liked - 287
# Liking....
# Liked - 288
# Liking....
# Liked - 289
# Liking....
# Liked - 290
# Disliking....
# Disliked - 114
# Liking....
# Liked - 291
# Liking....
# Liked - 292
# Liking....
# Liked - 293
# Disliking....
# Disliked - 115
# Disliking....
# Disliked - 116
# Liking....
# Liked - 294
# Liking....
# Liked - 295
# Liking....
# Liked - 296
# Liking....
# Liked - 297
# Liking....
# Liked - 298
# Disliking....
# Disliked - 117
# Liking....
# Liked - 299
# Liking....
# Liked - 300
# Liking....
# Liked - 301
# Disliking....
# Disliked - 118
# Disliking....
# Disliked - 119
# Liking....
# Liked - 302
# Liking....
# Liked - 303
# Disliking....
# Disliked - 120
# Liking....
# Liked - 304
# Liking....
# Liked - 305
# Liking....
# Liked - 306
# Liking....
# Liked - 307
# Liking....
# Liked - 308
# Disliking....
# Disliked - 121
# Liking....
# Liked - 309
# Liking....
# Liked - 310
# Liking....
# Liked - 311
# Liking....
# Liked - 312
# Disliking....
# Disliked - 122
# Disliking....
# Disliked - 123
# Liking....
# Liked - 313
# Liking....
# Liked - 314
# Liking....
# Liked - 315
# Disliking....
# Disliked - 124
# Liking....
# Liked - 316
# Liking....
# Liked - 317
# Disliking....
# Disliked - 125
# Liking....
# Liked - 318
# Disliking....
# Disliked - 126
# Disliking....
# Disliked - 127
# Liking....
# Liked - 319
# Liking....
# Liked - 320
# Liking....
# Liked - 321
# Liking....
# Liked - 322
# Disliking....
# Disliked - 128
# Disliking....
# Disliked - 129
# Liking....
# Liked - 323
# Liking....
# Liked - 324
# Liking....
# Liked - 325
# Liking....
# Liked - 326
# Liking....
# Liked - 327
# Disliking....
# Disliked - 130
# Liking....
# Liked - 328
# Disliking....
# Disliked - 131
# Liking....
# Liked - 329
# Liking....
# Liked - 330
# Liking....
# Liked - 331
# Liking....
# Liked - 332
# Liking....
# Liked - 333
# Disliking....
# Disliked - 132
# Liking....
# Liked - 334
# Disliking....
# Disliked - 133
# Liking....
# Liked - 335
# Disliking....
# Disliked - 134
# Liking....
# Liked - 336
# Liking....
# Liked - 337
# Disliking....
# Disliked - 135
# Liking....
# Liked - 338
# Liking....
# Liked - 339
# Disliking....
# Disliked - 136
# Liking....
# Liked - 340
# Liking....
# Liked - 341
# Liking....
# Liked - 342
# Liking....
# Liked - 343
# Liking....
# Liked - 344
# Disliking....
# Disliked - 137
# Disliking....
# Disliked - 138
# Liking....
# Liked - 345
# Liking....
# Liked - 346
# Liking....
# Liked - 347
# Disliking....
# Disliked - 139
# Liking....
# Liked - 348
# Liking....
# Liked - 349
# Liking....
# Liked - 350
# Liking....
# Liked - 351
# Disliking....
# Disliked - 140
# Liking....
# Liked - 352
# Liking....
# Liked - 353
# Liking....
# Liked - 354
# Disliking....
# Disliked - 141
# Liking....
# Liked - 355
# Liking....
# Liked - 356
# Disliking....
# Disliked - 142
# Liking....
# Liked - 357
# Liking....
# Liked - 358
# Disliking....
# Disliked - 143
# Liking....
# Liked - 359
# Liking....
# Liked - 360
# Disliking....
# Disliked - 144
# Disliking....
# Disliked - 145
# Liking....
# Liked - 361
# Liking....
# Liked - 362
# Liking....
# Liked - 363
# Liking....
# Liked - 364
# Liking....
# Liked - 365
# Disliking....
# Disliked - 146
# Liking....
# Liked - 366
# Liking....
# Liked - 367
# Liking....
# Liked - 368
# Liking....
# Liked - 369
# Disliking....
# Disliked - 147
# Liking....
# Liked - 370
# Disliking....
# Disliked - 148
# Liking....
# Liked - 371
# Liking....
# Liked - 372
# Liking....
# Liked - 373
# Liking....
# Liked - 374
# Liking....
# Liked - 375
# Disliking....
# Disliked - 149
# Liking....
# Liked - 376
# Liking....
# Liked - 377
# Disliking....
# Disliked - 150
# Liking....
# Liked - 378
# Liking....
# Liked - 379
# Liking....
# Liked - 380
# Disliking....
# Disliked - 151
# Liking....
# Liked - 381
# Liking....
# Liked - 382
# Liking....
# Liked - 383
# Disliking....
# Disliked - 152
# Liking....
# Liked - 384
# Liking....
# Liked - 385
# Liking....
# Liked - 386
# Liking....
# Liked - 387
# Liking....
# Liked - 388
# Disliking....
# Disliked - 153
# Liking....
# Liked - 389
# Liking....
# Liked - 390
# Liking....
# Liked - 391
# Liking....
# Liked - 392
# Liking....
# Liked - 393
# Disliking....
# Disliked - 154
# Liking....
# Liked - 394
# Liking....
# Liked - 395
# Liking....
# Liked - 396
# Liking....
# Liked - 397
# Liking....
# Liked - 398
# Disliking....
# Disliked - 155
# Liking....
# Liked - 399
# Disliking....
# Disliked - 156
# Liking....
# Liked - 400
# Liking....
# Liked - 401
# Disliking....
# Disliked - 157
# Liking....
# Liked - 402
# Liking....
# Liked - 403
# Liking....
# Liked - 404
# Liking....
# Liked - 405
# Liking....
# Liked - 406
# Disliking....
# Disliked - 158
# Liking....
# Liked - 407
# Liking....
# Liked - 408
# Liking....
# Liked - 409
# Disliking....
# Disliked - 159
# Liking....
# Liked - 410
# Liking....
